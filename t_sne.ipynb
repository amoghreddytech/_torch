# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
mean = 2
scale = 1
class_1 = np.random.normal(loc = 2, scale = 1, size = (250,2))
class_2 = np.random.normal(loc = -2, scale = 1, size = (750,2))
x = np.concatenate((class_1,class_2),axis = 0)
colors = ['blue','purple']
label = ["class1","class_2"]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(x[0:250,0], x[0:250,1], s=10, c='b', marker="s", label='first class')
ax1.scatter(x[250:1000,0],x[250:1000,1], s=10, c='r', marker="o", label='second class')
plt.legend(loc='upper left');
plt.show()

# %%
X_embedded = TSNE(n_components=2).fit_transform(x)
X_embedded.shape
# Out:
# (1000, 2)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(X_embedded[0:250,0], X_embedded[0:250,1], s=10, c='b', marker="s", label='first class')
ax1.scatter(X_embedded[250:1000,0],X_embedded[250:1000,1], s=10, c='r', marker="o", label='second class')
plt.legend(loc='upper left');
plt.show()

# %%
X_embedded = TSNE(n_components=2,n_iter=2000,perplexity=2).fit_transform(x)
X_embedded.shape

fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(X_embedded[0:250,0], X_embedded[0:250,1], s=10, c='b', marker="s", label='first class')
ax1.scatter(X_embedded[250:1000,0],X_embedded[250:1000,1], s=10, c='r', marker="o", label='second class')
plt.legend(loc='upper left');
plt.show()

# %%
X_embedded = TSNE(n_components=2,n_iter=2000,perplexity=10).fit_transform(x)


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(X_embedded[0:250,0], X_embedded[0:250,1], s=10, c='b', marker="s", label='first class')
ax1.scatter(X_embedded[250:1000,0],X_embedded[250:1000,1], s=10, c='r', marker="o", label='second class')
plt.legend(loc='upper left');
plt.show()

# %%
X_embedded = TSNE(n_components=2,n_iter=2000,perplexity=50).fit_transform(x)


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(X_embedded[0:250,0], X_embedded[0:250,1], s=10, c='b', marker="s", label='first class')
ax1.scatter(X_embedded[250:1000,0],X_embedded[250:1000,1], s=10, c='r', marker="o", label='second class')
plt.legend(loc='upper left');
plt.show()

# %%
X_embedded = TSNE(n_components=2,n_iter=2000,perplexity=1000).fit_transform(x)


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(X_embedded[0:250,0], X_embedded[0:250,1], s=10, c='b', marker="s", label='first class')
ax1.scatter(X_embedded[250:1000,0],X_embedded[250:1000,1], s=10, c='r', marker="o", label='second class')
plt.legend(loc='upper left');
plt.show()

# %%
X_embedded = TSNE(n_components=2,n_iter=250,perplexity=50).fit_transform(x)


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(X_embedded[0:250,0], X_embedded[0:250,1], s=10, c='b', marker="s", label='first class')
ax1.scatter(X_embedded[250:1000,0],X_embedded[250:1000,1], s=10, c='r', marker="o", label='second class')
plt.legend(loc='upper left');
plt.show()

# %%
X_embedded = TSNE(n_components=2,n_iter=500,perplexity=50).fit_transform(x)


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(X_embedded[0:250,0], X_embedded[0:250,1], s=10, c='b', marker="s", label='first class')
ax1.scatter(X_embedded[250:1000,0],X_embedded[250:1000,1], s=10, c='r', marker="o", label='second class')
plt.legend(loc='upper left');
plt.show()

# %%
X_embedded = TSNE(n_components=2,n_iter=750,perplexity=50).fit_transform(x)


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(X_embedded[0:250,0], X_embedded[0:250,1], s=10, c='b', marker="s", label='first class')
ax1.scatter(X_embedded[250:1000,0],X_embedded[250:1000,1], s=10, c='r', marker="o", label='second class')
plt.legend(loc='upper left');
plt.show()

# %%
X_embedded = TSNE(n_components=2,n_iter=1000,perplexity=50).fit_transform(x)


fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(X_embedded[0:250,0], X_embedded[0:250,1], s=10, c='b', marker="s", label='first class')
ax1.scatter(X_embedded[250:1000,0],X_embedded[250:1000,1], s=10, c='r', marker="o", label='second class')
plt.legend(loc='upper left');
plt.show()
